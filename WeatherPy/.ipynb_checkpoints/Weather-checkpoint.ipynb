# %%
import requests
import json
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as st 
import random
from citipy import citipy
from api_keys import (weather_api_key, gkey)

units = 'imperial'
query_url = f'http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units={units}&q='

# %%
# Generate Cities List
cities = []

# Generate random coordinates
lat = np.random.uniform(low = -90, high = 90, size=2000)
long = np.random.uniform(low = -180, high = 180, size=2000)
coordinates = list(zip(lat, long))

# For every set of coordinates:
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)
        
print(len(cities))
# Out:
# 758

# %%
# Perform API calls

# for city in cities:
#     raw_data = requests.get(query_url + city).json()
    
# print(raw_data)


raw_data = requests.get(query_url + 'denver').json()

print(raw_data)
# Out:
# {'coord': {'lon': -104.9847, 'lat': 39.7392}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 75.06, 'feels_like': 75.04, 'temp_min': 67.28, 'temp_max': 80.33, 'pressure': 1011, 'humidity': 59}, 'visibility': 10000, 'wind': {'speed': 1.99, 'deg': 109, 'gust': 7}, 'clouds': {'all': 100}, 'dt': 1626299908, 'sys': {'type': 2, 'id': 2004334, 'country': 'US', 'sunrise': 1626263028, 'sunset': 1626316047}, 'timezone': -21600, 'id': 5419384, 'name': 'Denver', 'cod': 200}

# %%
# Perform API calls

# Set initial count
Set = 1
rec_num = 0

# Lists to hold data
place_name = []
country = []
lon = []
lat = []
weather = []
temp = []
temp_max = []
temp_min = []
humidity = []
cloudiness = []
wind_speed = []


# for city in the cities list
for city in cities:
    
    # try to get weather data
    try:
        raw_data = requests.get(query_url + city).json()
        
        place_name.append(raw_data['name'])
        country.append(raw_data['sys']['country'])
        lon.append(raw_data['coord']['lon'])
        lat.append(raw_data['coord']['lat'])
        weather.append(raw_data['weather'][0]['description'])
        temp.append(raw_data['main']['temp'])
        temp_max.append(raw_data['main']['temp_max'])
        temp_min.append(raw_data['main']['temp_min'])
        humidity.append(raw_data['main']['humidity'])
        cloudiness.append(raw_data['clouds']['all'])
        wind_speed.append(raw_data['wind']['speed'])
        
        
        # Add one to the record number
        rec_num += 1
        
        # If the number you get is more than 50
        if rec_num > 50:
            
            # Start over counting from 1
            rec_num = 1
            
            # add one to the set
            Set += 1
            
        print(f"Processing Record {rec_num} of Set {Set} | {raw_data['name']}")
        
    except:
        print('City not found. Skipping...')
# Out:
# Processing Record 1 of Set 1 | Tuatapere
# Processing Record 2 of Set 1 | Fort Saint James
# Processing Record 3 of Set 1 | Cockburn Town
# Processing Record 4 of Set 1 | Tiksi
# Processing Record 5 of Set 1 | Bijapur
# Processing Record 6 of Set 1 | Madisonville
# Processing Record 7 of Set 1 | Tuktoyaktuk
# Processing Record 8 of Set 1 | Sinjār
# Processing Record 9 of Set 1 | Luanda
# Processing Record 10 of Set 1 | Hobart
# Processing Record 11 of Set 1 | Busselton
# Processing Record 12 of Set 1 | São João da Barra
# Processing Record 13 of Set 1 | Aracati
# City not found. Skipping...
# Processing Record 14 of Set 1 | Clyde River
# Processing Record 15 of Set 1 | Kushmurun
# Processing Record 16 of Set 1 | Adrar
# Processing Record 17 of Set 1 | Vestmannaeyjar
# Processing Record 18 of Set 1 | Vakhrushev
# Processing Record 19 of Set 1 | Saint-Philippe
# Processing Record 20 of Set 1 | Kaitangata
# Processing Record 1 of Set 4 | Olafsvik
# Processing Record 2 of Set 4 | Ostrovnoy
# Processing Record 3 of Set 4 | Miramar
# Processing Record 4 of Set 4 | Baltiysk
# Processing Record 5 of Set 4 | Tena
# Processing Record 6 of Set 4 | Asheville
# Processing Record 7 of Set 4 | Henties Bay
# Processing Record 8 of Set 4 | College
# Processing Record 9 of Set 4 | Vardø
# Processing Record 10 of Set 4 | Gigmoto
# Processing Record 11 of Set 4 | Ambon City
# Processing Record 12 of Set 4 | Barcelos
# Processing Record 13 of Set 4 | Sisimiut
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 14 of Set 4 | Tūkrah
# Processing Record 15 of Set 4 | Carnarvon
# Processing Record 16 of Set 4 | Ilulissat
# Processing Record 17 of Set 4 | Kaitong
# Processing Record 18 of Set 4 | Katsuura
# Processing Record 19 of Set 4 | Paamiut
# Processing Record 20 of Set 4 | Doka
# Processing Record 21 of Set 4 | Mount Isa
# Processing Record 22 of Set 4 | Krasnaya Polyana
# Processing Record 23 of Set 4 | Khatanga
# City not found. Skipping...
# Processing Record 24 of Set 4 | Christchurch
# Processing Record 25 of Set 4 | Wasco
# Processing Record 26 of Set 4 | Dafeng
# Processing Record 27 of Set 4 | Nikolskoye
# Processing Record 28 of Set 4 | Beringovskiy
# Processing Record 29 of Set 4 | Ust-Kuyga
# Processing Record 30 of Set 4 | Douglas
# Processing Record 31 of Set 4 | Lata
# Processing Record 32 of Set 4 | Mehamn
# Processing Record 33 of Set 4 | Elliot
# Processing Record 34 of Set 4 | Salalah
# Processing Record 35 of Set 4 | Ulaangom
# Processing Record 36 of Set 4 | Batouri
# Processing Record 37 of Set 4 | Hobyo
# Processing Record 38 of Set 4 | Cidreira
# Processing Record 39 of Set 4 | Kristiansund
# Processing Record 40 of Set 4 | Esperance
# City not found. Skipping...
# Processing Record 41 of Set 4 | Bengkulu
# Processing Record 42 of Set 4 | Vila Franca do Campo
# City not found. Skipping...
# Processing Record 43 of Set 4 | Mercedes
# Processing Record 44 of Set 4 | Raudeberg
# Processing Record 45 of Set 4 | Haapiti
# Processing Record 46 of Set 4 | Bilma
# Processing Record 47 of Set 4 | Mar del Plata
# Processing Record 48 of Set 4 | Endirey
# Processing Record 49 of Set 4 | Hilo
# Processing Record 50 of Set 4 | New Norfolk
# Processing Record 1 of Set 5 | Itoman
# City not found. Skipping...
# Processing Record 2 of Set 5 | Pangody
# Processing Record 3 of Set 5 | Ngunguru
# Processing Record 4 of Set 5 | Naze
# Processing Record 5 of Set 5 | Kumul
# Processing Record 6 of Set 5 | Samarai
# Processing Record 7 of Set 5 | Solnechnyy
# Processing Record 8 of Set 5 | Resistencia
# Processing Record 9 of Set 5 | Shimoda
# Processing Record 10 of Set 5 | Idrinskoye
# Processing Record 11 of Set 5 | Lingsugūr
# Processing Record 12 of Set 5 | Balsas
# Processing Record 13 of Set 5 | Charters Towers
# Processing Record 14 of Set 5 | Vizinga
# Processing Record 15 of Set 5 | Shouguang
# Processing Record 16 of Set 5 | Wamba
# Processing Record 17 of Set 5 | Sakakah
# Processing Record 18 of Set 5 | Cap Malheureux
# City not found. Skipping...
# Processing Record 19 of Set 5 | Hasaki
# Processing Record 20 of Set 5 | Siliguri
# City not found. Skipping...
# Processing Record 21 of Set 5 | Flagstaff
# Processing Record 22 of Set 5 | Sikonge
# City not found. Skipping...
# Processing Record 23 of Set 5 | Petropavlovsk-Kamchatskiy
# Processing Record 24 of Set 5 | Port Moresby
# Processing Record 25 of Set 5 | Acajutla
# Processing Record 26 of Set 5 | Zhangaözen
# Processing Record 27 of Set 5 | Atasū
# Processing Record 28 of Set 5 | Fairbanks
# Processing Record 29 of Set 5 | Visakhapatnam
# Processing Record 30 of Set 5 | Fare
# Processing Record 31 of Set 5 | Kapoeta
# Processing Record 32 of Set 5 | Mattru
# Processing Record 33 of Set 5 | Alice Springs
# Processing Record 34 of Set 5 | Mehrān
# Processing Record 35 of Set 5 | Kampong Cham
# Processing Record 36 of Set 5 | Port Blair
# Processing Record 37 of Set 5 | Mahébourg
# Processing Record 38 of Set 5 | Nioki
# Processing Record 39 of Set 5 | Sémbé
# Processing Record 40 of Set 5 | Gijang
# Processing Record 41 of Set 5 | Waipawa
# Processing Record 42 of Set 5 | San Jerónimo
# Processing Record 43 of Set 5 | Imbituba
# Processing Record 44 of Set 5 | Bereda
# Processing Record 45 of Set 5 | Kurumkan
# Processing Record 46 of Set 5 | Nelson Bay
# Processing Record 47 of Set 5 | Sur
# Processing Record 48 of Set 5 | South Lake Tahoe
# City not found. Skipping...
# Processing Record 49 of Set 5 | Samaná
# Processing Record 50 of Set 5 | Zelenoborskiy
# Processing Record 1 of Set 6 | Lagoa
# Processing Record 2 of Set 6 | Bogdanovich
# City not found. Skipping...
# Processing Record 3 of Set 6 | Griffith
# Processing Record 4 of Set 6 | Antofagasta
# Processing Record 5 of Set 6 | Ponta do Sol
# Processing Record 6 of Set 6 | Ca Mau
# Processing Record 7 of Set 6 | Guerrero Negro
# Processing Record 8 of Set 6 | Oshkosh
# Processing Record 9 of Set 6 | Terrace
# Processing Record 10 of Set 6 | Meulaboh
# Processing Record 11 of Set 6 | Graaff-Reinet
# Processing Record 12 of Set 6 | Portland
# Processing Record 13 of Set 6 | Haines Junction
# Processing Record 14 of Set 6 | Yangi Marg`ilon
# Processing Record 15 of Set 6 | Grand Gaube
# City not found. Skipping...
# Processing Record 16 of Set 6 | Torbay
# Processing Record 17 of Set 6 | Maracás
# Processing Record 18 of Set 6 | La Ronge
# Processing Record 19 of Set 6 | Pitimbu
# Processing Record 20 of Set 6 | Changli
# Processing Record 21 of Set 6 | St. Marys
# Processing Record 22 of Set 6 | Alofi
# Processing Record 23 of Set 6 | Longyearbyen
# Processing Record 24 of Set 6 | Lokosovo
# Processing Record 25 of Set 6 | Bara
# Processing Record 26 of Set 6 | Toamasina
# Processing Record 27 of Set 6 | ‘Āhuimanu
# Processing Record 28 of Set 6 | Fort Walton Beach
# Processing Record 29 of Set 6 | Lompoc
# Processing Record 30 of Set 6 | Haicheng
# Processing Record 31 of Set 6 | Suntar
# Processing Record 32 of Set 6 | Elko
# Processing Record 33 of Set 6 | Pozo Colorado
# Processing Record 34 of Set 6 | Norman Wells
# Processing Record 35 of Set 6 | Bentiu
# Processing Record 36 of Set 6 | Ruwi
# Processing Record 37 of Set 6 | Belozërskoye
# Processing Record 38 of Set 6 | Esso
# Processing Record 39 of Set 6 | Leh
# Processing Record 40 of Set 6 | Atar
# Processing Record 41 of Set 6 | Mosetse
# City not found. Skipping...
# Processing Record 42 of Set 6 | Marsh Harbour
# Processing Record 43 of Set 6 | Chicama
# Processing Record 44 of Set 6 | Jumla
# City not found. Skipping...
# Processing Record 45 of Set 6 | Forrest City
# Processing Record 46 of Set 6 | Yumen
# Processing Record 47 of Set 6 | Ratangarh
# Processing Record 48 of Set 6 | Fortuna
# Processing Record 49 of Set 6 | Ahipara
# Processing Record 50 of Set 6 | Sitka
# Processing Record 1 of Set 7 | Végueta
# City not found. Skipping...
# Processing Record 2 of Set 7 | Dikson
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 3 of Set 7 | Marang
# Processing Record 4 of Set 7 | Ambilobe
# Processing Record 5 of Set 7 | Burnie
# Processing Record 6 of Set 7 | Sola
# Processing Record 7 of Set 7 | Yachiyo
# Processing Record 8 of Set 7 | Vezirköprü
# Processing Record 9 of Set 7 | Ust'-Kalmanka
# City not found. Skipping...
# Processing Record 10 of Set 7 | Dillon
# Processing Record 11 of Set 7 | Passos
# Processing Record 12 of Set 7 | Gushikawa
# Processing Record 13 of Set 7 | Severnoye
# Processing Record 14 of Set 7 | Mandalgovi
# Processing Record 15 of Set 7 | Loum
# Processing Record 16 of Set 7 | Dzhebariki-Khaya
# Processing Record 17 of Set 7 | Rio Grande
# Processing Record 18 of Set 7 | Shimanovsk
# Processing Record 19 of Set 7 | Havre-St-Pierre
# Processing Record 20 of Set 7 | Porto-Novo
# Processing Record 21 of Set 7 | Airai
# Processing Record 22 of Set 7 | Morondava
# Processing Record 23 of Set 7 | Kiruna
# Processing Record 24 of Set 7 | Takoradze
# Processing Record 25 of Set 7 | Antequera
# Processing Record 26 of Set 7 | Madang
# Processing Record 27 of Set 7 | Grand-Santi
# Processing Record 28 of Set 7 | Ta Khmau
# Processing Record 29 of Set 7 | Mossamedes
# Processing Record 30 of Set 7 | Sandane
# City not found. Skipping...
# Processing Record 31 of Set 7 | Kaseda-shirakame
# City not found. Skipping...
# Processing Record 32 of Set 7 | Flin Flon
# Processing Record 33 of Set 7 | Masterton
# City not found. Skipping...
# Processing Record 34 of Set 7 | Lakselv
# Processing Record 35 of Set 7 | Yertsevo
# City not found. Skipping...
# Processing Record 36 of Set 7 | Portree
# Processing Record 37 of Set 7 | Pop
# Processing Record 38 of Set 7 | Tortolì
# Processing Record 39 of Set 7 | Maumere
# Processing Record 40 of Set 7 | Atagay
# Processing Record 41 of Set 7 | Nova Prata
# Processing Record 42 of Set 7 | Krasnyy Chikoy
# Processing Record 6 of Set 9 | Peniche
# Processing Record 7 of Set 9 | Qom
# Processing Record 8 of Set 9 | Maple Valley
# Processing Record 9 of Set 9 | Golyshmanovo
# Processing Record 10 of Set 9 | Muros
# Processing Record 11 of Set 9 | Bafoulabé
# Processing Record 12 of Set 9 | Sal Rei
# Processing Record 13 of Set 9 | Ossora
# Processing Record 14 of Set 9 | Marystown
# Processing Record 15 of Set 9 | Poço Verde
# Processing Record 16 of Set 9 | Whitehorse
# Processing Record 17 of Set 9 | Saint-Pierre
# Processing Record 18 of Set 9 | Paracuru
# Processing Record 19 of Set 9 | Kuril'sk
# Processing Record 20 of Set 9 | Iqaluit
# Processing Record 21 of Set 9 | Touros
# Processing Record 22 of Set 9 | Ilaya
# Processing Record 23 of Set 9 | Nome
# Processing Record 24 of Set 9 | Pacific Grove
# Processing Record 25 of Set 9 | Poso
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 26 of Set 9 | Pouembout
# Processing Record 27 of Set 9 | Pangai
# Processing Record 28 of Set 9 | Pilar
# Processing Record 29 of Set 9 | Yulara
# Processing Record 30 of Set 9 | Saryg-Sep
# Processing Record 31 of Set 9 | Ankazobe
# Processing Record 32 of Set 9 | Saint George
# Processing Record 33 of Set 9 | Terrace Bay
# Processing Record 34 of Set 9 | Vanavara
# Processing Record 35 of Set 9 | Mantenópolis
# Processing Record 36 of Set 9 | Vozuća
# Processing Record 37 of Set 9 | Bambanglipuro
# Processing Record 38 of Set 9 | Kontagora
# Processing Record 39 of Set 9 | Zhigansk
# Processing Record 40 of Set 9 | Zyryanka
# Processing Record 41 of Set 9 | Karasjok
# Processing Record 42 of Set 9 | Pak Chong
# City not found. Skipping...
# Processing Record 43 of Set 9 | Būlaevo
# Processing Record 44 of Set 9 | Bayan
# Processing Record 45 of Set 9 | Mutare
# Processing Record 46 of Set 9 | Cilegon
# Processing Record 47 of Set 9 | Vao
# Processing Record 48 of Set 9 | Shihezi
# Processing Record 49 of Set 9 | Port Hardy
# Processing Record 50 of Set 9 | Yakima
# Processing Record 1 of Set 10 | Manokwari
# Processing Record 2 of Set 10 | Talnakh
# Processing Record 3 of Set 10 | Carutapera
# Processing Record 4 of Set 10 | Pierre
# Processing Record 5 of Set 10 | Yarmouth
# Processing Record 6 of Set 10 | Nemuro
# Processing Record 7 of Set 10 | Río Gallegos
# Processing Record 8 of Set 10 | Bāfq
# Processing Record 9 of Set 10 | Cabedelo
# Processing Record 10 of Set 10 | Sokol
# Processing Record 11 of Set 10 | Noci
# Processing Record 12 of Set 10 | Nizwá
# Processing Record 13 of Set 10 | Borgo San Lorenzo
# Processing Record 14 of Set 10 | Grants
# Processing Record 15 of Set 10 | Hofn
# Processing Record 16 of Set 10 | Rocky Mountain House
# Processing Record 17 of Set 10 | Micheweni
# Processing Record 18 of Set 10 | Bulgan
# Processing Record 19 of Set 10 | Pisco
# Processing Record 20 of Set 10 | Golspie
# Processing Record 21 of Set 10 | Iberia
# Processing Record 22 of Set 10 | Mahibadhoo
# City not found. Skipping...
# Processing Record 23 of Set 10 | San Ramon
# Processing Record 24 of Set 10 | Kidal
# Processing Record 25 of Set 10 | Chilchota
# Processing Record 26 of Set 10 | Novy Urengoy
# Processing Record 27 of Set 10 | Stornoway
# Processing Record 28 of Set 10 | Bolshaya Sosnova
# Processing Record 29 of Set 10 | Dickinson
# Processing Record 30 of Set 10 | Atambua
# Processing Record 31 of Set 10 | Pangnirtung
# Processing Record 32 of Set 10 | Saldanha
# Processing Record 33 of Set 10 | Kirakira
# Processing Record 34 of Set 10 | Viedma
# Processing Record 35 of Set 10 | Lázaro Cárdenas
# City not found. Skipping...
# Processing Record 36 of Set 10 | Buraidah
# Processing Record 37 of Set 10 | Ndola
# Processing Record 38 of Set 10 | Verkhnevilyuysk
# Processing Record 39 of Set 10 | Chkalovskoye
# Processing Record 40 of Set 10 | Balkanabat
# Processing Record 41 of Set 10 | Praia da Vitória
# Processing Record 42 of Set 10 | Władysławowo
# Processing Record 43 of Set 10 | Sidi Ali
# Processing Record 44 of Set 10 | Morehead
# Processing Record 45 of Set 10 | Casambalangan
# Processing Record 46 of Set 10 | Vila do Maio
# Processing Record 47 of Set 10 | San Jose
# Processing Record 48 of Set 10 | Nouadhibou
# Processing Record 49 of Set 10 | Hamilton
# Processing Record 50 of Set 10 | Sangar
# Processing Record 1 of Set 11 | Anadyr
# Processing Record 2 of Set 11 | Port Hedland
# Processing Record 3 of Set 11 | Bumba
# Processing Record 4 of Set 11 | Shahreza
# Processing Record 5 of Set 11 | Makat
# Processing Record 6 of Set 11 | Nantucket
# Processing Record 7 of Set 11 | Āsbe Teferī
# Processing Record 8 of Set 11 | Cairns
# Processing Record 9 of Set 11 | Vanino
# Processing Record 10 of Set 11 | Fendou
# Processing Record 11 of Set 11 | Palimé
# Processing Record 12 of Set 11 | Riohacha
# Processing Record 13 of Set 11 | Galesong
# Processing Record 14 of Set 11 | Slave Lake
# Processing Record 15 of Set 11 | Corinth
# Processing Record 16 of Set 11 | Pemberton
# Processing Record 17 of Set 11 | Warrnambool
# Processing Record 18 of Set 11 | Tabou
# Processing Record 19 of Set 11 | Cheyenne
# Processing Record 20 of Set 11 | Mīzan Teferī
# Processing Record 21 of Set 11 | Houndé
# Processing Record 22 of Set 11 | Cherskiy
# Processing Record 23 of Set 11 | Laguna
# Processing Record 24 of Set 11 | Tongzi
# Processing Record 25 of Set 11 | Nālūt
# Processing Record 26 of Set 11 | Payson
# Processing Record 27 of Set 11 | Bonthe
# Processing Record 28 of Set 11 | Fatick
# Processing Record 29 of Set 11 | Nizhniy Kuranakh
# Processing Record 30 of Set 11 | Quryq
# Processing Record 31 of Set 11 | Bogandé
# Processing Record 32 of Set 11 | Şile
# Processing Record 33 of Set 11 | Leer
# City not found. Skipping...
# Processing Record 34 of Set 11 | Sampit
# Processing Record 35 of Set 11 | Majene
# Processing Record 36 of Set 11 | Moss Point
# City not found. Skipping...
# Processing Record 37 of Set 11 | Wajima
# Processing Record 38 of Set 11 | Vila Velha
# Processing Record 39 of Set 11 | Pekan
# Processing Record 40 of Set 11 | Aklavik
# Processing Record 41 of Set 11 | Pangoa
# Processing Record 42 of Set 11 | Port Keats
# Processing Record 43 of Set 11 | Carupano
# Processing Record 44 of Set 11 | Mackenzie
# Processing Record 45 of Set 11 | Bafang
# Processing Record 46 of Set 11 | Hualmay
# City not found. Skipping...
# Processing Record 47 of Set 11 | Årøysund
# Processing Record 48 of Set 11 | Turukhansk
# Processing Record 49 of Set 11 | Narón
# Processing Record 50 of Set 11 | Oranjemund
# Processing Record 1 of Set 12 | Chifeng
# Processing Record 2 of Set 12 | Starovelichkovskaya
# Processing Record 3 of Set 12 | Hervey Bay
# City not found. Skipping...
# Processing Record 4 of Set 12 | Lorengau
# Processing Record 5 of Set 12 | Sobolevo
# Processing Record 6 of Set 12 | Province of Mantua
# Processing Record 7 of Set 12 | Pedernales
# Processing Record 8 of Set 12 | Suffolk
# Processing Record 9 of Set 12 | Zhangjiakou
# City not found. Skipping...
# Processing Record 10 of Set 12 | Hermiston
# Processing Record 11 of Set 12 | Tahoua
# Processing Record 12 of Set 12 | Marstal
# Processing Record 13 of Set 12 | Orotukan
# City not found. Skipping...
# Processing Record 14 of Set 12 | Pontes e Lacerda
# Processing Record 15 of Set 12 | Korla
# Processing Record 16 of Set 12 | Les Cayes
# Processing Record 17 of Set 12 | Barsovo
# Processing Record 18 of Set 12 | Blackwater
# Processing Record 19 of Set 12 | Tilichiki
# Processing Record 20 of Set 12 | Arrifes
# Processing Record 21 of Set 12 | Balikpapan
# City not found. Skipping...
# Processing Record 22 of Set 12 | Kiryat Gat
# Processing Record 23 of Set 12 | City of San Pedro
# Processing Record 24 of Set 12 | Pyapon
# Processing Record 25 of Set 12 | Tura
# Processing Record 26 of Set 12 | Honningsvåg
# Processing Record 27 of Set 12 | Zaragoza
# City not found. Skipping...
# Processing Record 28 of Set 12 | Topeka
# Processing Record 29 of Set 12 | Izhma
# Processing Record 30 of Set 12 | Aykhal
# Processing Record 31 of Set 12 | Saint-Augustin
# Processing Record 32 of Set 12 | Riverton
# City not found. Skipping...
# Processing Record 33 of Set 12 | Abalak
# Processing Record 34 of Set 12 | Barranca
# Processing Record 35 of Set 12 | Saint-Gabriel
# Processing Record 36 of Set 12 | Wonthaggi
# Processing Record 37 of Set 12 | Salinópolis
# Processing Record 38 of Set 12 | Marsá Maţrūḩ
# Processing Record 39 of Set 12 | Lafia
# Processing Record 40 of Set 12 | Sinnamary
# Processing Record 41 of Set 12 | Olinda
# Processing Record 42 of Set 12 | San Quintín
# City not found. Skipping...
# Processing Record 43 of Set 12 | Kropotkin
# Processing Record 44 of Set 12 | Mubi
# Processing Record 45 of Set 12 | Bangaon
# Processing Record 46 of Set 12 | Acaraú
# Processing Record 47 of Set 12 | Brae
# City not found. Skipping...
# Processing Record 48 of Set 12 | Pimenta Bueno
# Processing Record 49 of Set 12 | Talara
# Processing Record 50 of Set 12 | Camacha
# Processing Record 1 of Set 13 | Evensk
# Processing Record 2 of Set 13 | Diapaga
# Processing Record 3 of Set 13 | Abhā
# Processing Record 4 of Set 13 | Tautira
# Processing Record 5 of Set 13 | Pārvatipuram
# Processing Record 6 of Set 13 | Bridlington
# Processing Record 7 of Set 13 | Taunggyi
# Processing Record 8 of Set 13 | Feldkirchen-Westerham
# Processing Record 9 of Set 13 | Venado Tuerto
# Processing Record 10 of Set 13 | Hare Bay
# Processing Record 11 of Set 13 | Atbasar
# Processing Record 12 of Set 13 | Okhotsk
# Processing Record 13 of Set 13 | Tabuk
# Processing Record 14 of Set 13 | Itaperuçu
# Processing Record 15 of Set 13 | Parnamirim
# Processing Record 16 of Set 13 | Egvekinot
# Processing Record 17 of Set 13 | Mount Gambier
# Processing Record 18 of Set 13 | Tongchuanshi
# Processing Record 19 of Set 13 | Tiznit Province
# Processing Record 20 of Set 13 | Batagay-Alyta
# Processing Record 21 of Set 13 | Guamo
# Processing Record 22 of Set 13 | Shache
# Processing Record 23 of Set 13 | Varhaug
# Processing Record 24 of Set 13 | Tarko-Sale
# Processing Record 25 of Set 13 | Maiduguri
# Processing Record 26 of Set 13 | Quelimane
# Processing Record 27 of Set 13 | Omboué
# Processing Record 28 of Set 13 | Leiyang
# City not found. Skipping...
# Processing Record 29 of Set 13 | Eyrarbakki
# Processing Record 30 of Set 13 | Goba
# City not found. Skipping...
# Processing Record 31 of Set 13 | Salinas
# Processing Record 32 of Set 13 | Darhan
# Processing Record 33 of Set 13 | Rawson
# Processing Record 34 of Set 13 | Tessaoua
# Processing Record 35 of Set 13 | Nangomba
# Processing Record 36 of Set 13 | Sterling
# Processing Record 37 of Set 13 | Launceston
# Processing Record 38 of Set 13 | Neuquén
# Processing Record 39 of Set 13 | Kungurtug
# Processing Record 40 of Set 13 | Ergani
# Processing Record 41 of Set 13 | Torit
# Processing Record 42 of Set 13 | Meybod
# Processing Record 43 of Set 13 | Ayan
# Processing Record 44 of Set 13 | Austin
# Processing Record 45 of Set 13 | Teplyk
# Processing Record 46 of Set 13 | Nakambala
# Processing Record 47 of Set 13 | Sadu
# Processing Record 48 of Set 13 | Dabakala
# Processing Record 49 of Set 13 | Saint-Paul
# Processing Record 50 of Set 13 | Bintulu
# Processing Record 1 of Set 14 | Severnyy
# Processing Record 2 of Set 14 | San Andrés
# Processing Record 3 of Set 14 | Kangaatsiaq
# Processing Record 4 of Set 14 | San Patricio
# Processing Record 5 of Set 14 | Praia
# Processing Record 6 of Set 14 | Dunedin
# Processing Record 7 of Set 14 | Montepuez
# Processing Record 8 of Set 14 | Cam Ranh
# Processing Record 9 of Set 14 | Luang Prabang
# Processing Record 10 of Set 14 | Hemsedal
# Processing Record 11 of Set 14 | Bundaberg
# Processing Record 12 of Set 14 | Maniitsoq
# Processing Record 13 of Set 14 | Katangli
# Processing Record 14 of Set 14 | Grand-Lahou
# Processing Record 15 of Set 14 | Tapes
# Processing Record 16 of Set 14 | Concepción
# Processing Record 17 of Set 14 | Payo
# Processing Record 18 of Set 14 | Helong
# Processing Record 19 of Set 14 | Deputatsky
# Processing Record 20 of Set 14 | Paoua
# Processing Record 21 of Set 14 | Kanuma
# Processing Record 22 of Set 14 | Kudahuvadhoo
# Processing Record 23 of Set 14 | Kumluca
# Processing Record 24 of Set 14 | Champerico
# Processing Record 25 of Set 14 | Gurgaon
# Processing Record 26 of Set 14 | Minot
# Processing Record 27 of Set 14 | Port Hawkesbury
# Processing Record 28 of Set 14 | Davila
# Processing Record 29 of Set 14 | Rundu
# Processing Record 30 of Set 14 | Gravdal
# Processing Record 31 of Set 14 | Sayyan
# Processing Record 32 of Set 14 | Orocué
# Processing Record 33 of Set 14 | Vágur
# Processing Record 34 of Set 14 | Maragogi
# Processing Record 35 of Set 14 | Emerald
# Processing Record 36 of Set 14 | Nioro
# Processing Record 37 of Set 14 | Kargasok
# Processing Record 38 of Set 14 | Makkah al Mukarramah
# Processing Record 39 of Set 14 | Yar-Sale
# Processing Record 40 of Set 14 | Zhicheng
# Processing Record 41 of Set 14 | Maceió

# %%
# Create DataFrame

weather_data = {"City": place_name, 
              "Country": country, 
              "Longitude": lon, 
              "Latitude": lat, 
              "Weather": weather,
              "Temp": temp,
              "Temp (Max)": temp_max,
              "Temp (Min)": temp_min,
              "Humidity": humidity,
              "Cloudiness": cloudiness,
              "Wind Speed": wind_speed}

weather_df = pd.DataFrame(weather_data)
weather_df = weather_df.set_index('City')
# Out:
#                      Country  Longitude  Latitude           Weather   Temp  \
# City
# Tuatapere                 NZ   167.6833  -46.1333     broken clouds  43.83
# Fort Saint James          CA  -124.2500   54.4333  scattered clouds  80.60
# Cockburn Town             TC   -71.1419   21.4612        few clouds  81.05
# Tiksi                     RU   128.8694   71.6872   overcast clouds  43.93
# Bijapur                   IN    75.7000   16.8333   overcast clouds  71.47
# ...                      ...        ...       ...               ...    ...
# Kargasok                  RU    80.8572   59.0556     broken clouds  60.60
# Makkah al Mukarramah      SA    39.8261   21.4267  scattered clouds  88.66
# Yar-Sale                  RU    70.8333   66.8333         clear sky  43.79
# Zhicheng                  CN   111.5047   30.2956        light rain  80.60
# Maceió                    BR   -35.7353   -9.6658  scattered clouds  76.44
#
#                       Temp (Max)  Temp (Min)  Humidity  Cloudiness  Wind Speed
# City
# Tuatapere                  43.83       43.83        78          70        2.37
# Fort Saint James           80.60       80.60        23          28        8.81
# Cockburn Town              81.05       81.05        75          18       15.50
# Tiksi                      43.93       43.93        68          91       20.49
# Bijapur                    71.47       71.47        89         100       20.07
# ...                          ...         ...       ...         ...         ...
# Kargasok                   60.60       60.60        95          54       12.01
# Makkah al Mukarramah       88.66       88.66        26          43        5.95
# Yar-Sale                   43.79       43.79        65           6        5.82
# Zhicheng                   80.60       80.60        82          62        3.29
# Maceió                     76.44       76.44        83          40        4.61
#
# [691 rows x 10 columns]

# %%
# find cities with humidity over 100
weather_df[weather_df["Humidity"]>100]
# Out:
# Empty DataFrame
# Columns: [City, Country, Longitude, Latitude, Weather, Temp, Temp (Max), Temp (Min), Humidity, Cloudiness, Wind Speed]
# Index: []

# %%
# Latitude vs. Temperature Plot
weather_df.plot.scatter("Latitude", "Temp")
plt.title('Latitude vs. Temperature')
# Out:
# Text(0.5, 1.0, 'Latitude vs. Temperature')

# %%
# Latitude vs. Humidity Plot
weather_df.plot.scatter("Latitude", "Humidity")
plt.title('Latitude vs. Humidity')
# Out:
# Text(0.5, 1.0, 'Latitude vs. Humidity')

# %%
# Latitude vs. Cloudiness Plot
weather_df.plot.scatter("Latitude", "Cloudiness")
plt.title('Latitude vs. Cloudiness')
# Out:
# Text(0.5, 1.0, 'Latitude vs. Cloudiness')

# %%
# Latitude vs. Wind Speed Plot
weather_df.plot.scatter("Latitude", "Wind Speed")
plt.title('Latitude vs. Wind Speed')
# Out:
# Text(0.5, 1.0, 'Latitude vs. Wind Speed')

# %%
# Northern Hemisphere - Max Temp vs. Latitude Linear Regression
NH_df = weather_df[(weather_df['Latitude'] > 0)]
NH_df.plot.scatter("Latitude", "Temp (Max)")
plt.title('Northern Hemisphere: Latitude vs. Max Temperature')
# Out:
# Text(0.5, 1.0, 'Northern Hemisphere: Latitude vs. Max Temperature')

# %%
# Southern Hemisphere - Max Temp vs. Latitude Linear Regression
SH_df = weather_df[(weather_df['Latitude'] < 0)]
SH_df.plot.scatter("Latitude", "Temp (Max)")
plt.title('Southern Hemisphere: Latitude vs. Max Temperature')
# Out:
# Text(0.5, 1.0, 'Southern Hemisphere: Latitude vs. Max Temperature')

# %%
# Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression
NH_df.plot.scatter("Latitude", "Humidity")
plt.title('Northern Hemisphere: Latitude vs. Humidity (%)')
# Out:
# Text(0.5, 1.0, 'Northern Hemisphere: Latitude vs. Humidity (%)')

# %%
# Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression
SH_df.plot.scatter("Latitude", "Humidity")
plt.title('Southern Hemisphere: Latitude vs. Humidity (%)')
# Out:
# Text(0.5, 1.0, 'Southern Hemisphere: Latitude vs. Humidity (%)')

# %%
# Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression
NH_df.plot.scatter("Latitude", "Cloudiness")
plt.title('Northern Hemisphere: Latitude vs. Cloudiness (%)')
# Out:
# Text(0.5, 1.0, 'Northern Hemisphere: Latitude vs. Cloudiness (%)')

# %%
# Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression
SH_df.plot.scatter("Latitude", "Cloudiness")
plt.title('Southern Hemisphere: Latitude vs. Cloudiness (%)')
# Out:
# Text(0.5, 1.0, 'Southern Hemisphere: Latitude vs. Cloudiness (%)')

# %%
# Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
NH_df.plot.scatter("Latitude", "Wind Speed")
plt.title('Northern Hemisphere: Latitude vs. Wind Speed (mph)')
# Out:
# Text(0.5, 1.0, 'Northern Hemisphere: Latitude vs. Wind Speed (mph)')

# %%
# Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
SH_df.plot.scatter("Latitude", "Wind Speed")
plt.title('Southern Hemisphere: Latitude vs. Wind Speed (mph)')
# Out:
# Text(0.5, 1.0, 'Southern Hemisphere: Latitude vs. Wind Speed (mph)')
